# %%
from openbb import obb
unemployment = obb.economy.unemployment()

# %%
df = unemployment.to_dataframe()
df
# Out:
#                   country  value
# date
# 1955-01-01  united_states  0.058
# 1955-02-01  united_states  0.057
# 1955-03-01  united_states  0.052
# 1955-04-01  united_states  0.049
# 1955-05-01  united_states  0.042
# ...                   ...    ...
# 2025-06-01  united_states  0.044
# 2025-07-01  united_states  0.046
# 2025-08-01  united_states  0.045
# 2025-09-01  united_states  0.043
# 2025-11-01  united_states  0.043
#
# [850 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# Pivot data for plotting
pivot_df = df.pivot(columns='country', values='value')

# Create plot
plt.figure(figsize=(14, 8))
for country in pivot_df.columns:
    plt.plot(pivot_df.index, pivot_df[country], label=country, alpha=0.7)

plt.title('Unemployment')
plt.xlabel('Year')
plt.ylabel('USD')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from openbb import obb
# Multiple countries can be passed in as a list.
spi = obb.economy.share_price_index(country='united_kingdom,germany,united_states', frequency='quarter')

# %%
df = spi.to_dataframe()
df
# Out:
#                    country       value
# date
# 1958-01-01  united_kingdom    1.521175
# 1958-01-01   united_states    2.327255
# 1958-04-01  united_kingdom    1.665800
# 1958-04-01   united_states    2.396252
# 1958-07-01  united_kingdom    1.813910
# ...                    ...         ...
# 2025-04-01  united_kingdom  129.944600
# 2025-04-01   united_states  181.390900
# 2025-07-01         germany  154.054900
# 2025-07-01  united_kingdom  138.464400
# 2025-07-01   united_states  195.955600
#
# [805 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# Pivot data for plotting
pivot_df = df.pivot(columns='country', values='value')

# Create plot
plt.figure(figsize=(14, 8))
for country in pivot_df.columns:
    plt.plot(pivot_df.index, pivot_df[country], label=country, alpha=0.7)

plt.title('Unemployment')
plt.xlabel('Year')
plt.ylabel('USD')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from openbb import obb
historical = obb.equity.price.historical(symbol='AMZN', interval="1d")

# %%
df = historical.to_dataframe()
df
# Out:
#               open    high     low   close     volume
# date
# 2004-01-02    2.64    2.66    2.57    2.60  132797998
# 2004-01-05    2.60    2.68    2.57    2.66  225681996
# 2004-01-06    2.66    2.68    2.64    2.65  119709998
# 2004-01-07    2.61    2.63    2.55    2.60  184853997
# 2004-01-08    2.60    2.61    2.50    2.51  206405996
# ...            ...     ...     ...     ...        ...
# 2025-10-24  221.97  225.40  221.90  224.21   38685053
# 2025-10-27  227.80  228.40  225.54  226.97   38266995
# 2025-10-28  228.20  231.49  226.21  229.25   47100026
# 2025-10-29  231.71  232.82  227.76  230.30   52036151
# 2025-10-30  227.20  228.44  222.75  222.86  102252937
#
# [5494 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# Pivot data for plotting
# pivot_df = df.pivot(columns='close', values='close')

# Create plot
plt.figure(figsize=(14, 8))
plt.plot(df.index, df['close'],  alpha=0.7)

plt.title('Stock price')
plt.xlabel('Year')
plt.ylabel('USD')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/h8/jfb1sfjx27sb056kh5343qph0000gn/T/ipykernel_18632/619662885.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %%
from openbb import obb
filings = obb.equity.fundamental.filings(symbol='NVDA')

# %%
df = filings.to_dataframe()
df
# Out:
#     filing_date report_type  \
# 0    2025-10-31           4
# 1    2025-10-29         144
# 2    2025-10-28           4
# 3    2025-10-28         144
# 4    2025-10-27         144
# ..          ...         ...
# 995  2019-05-24           4
# 996  2019-05-24           4
# 997  2019-05-21     CORRESP
# 998  2019-05-16         8-K
# 999  2019-05-16        10-Q
#
#                                             report_url report_date act  \
# 0    https://www.sec.gov/Archives/edgar/data/104581...  2025-10-29
# 1    https://www.sec.gov/Archives/edgar/data/104581...         NaN  33
# 2    https://www.sec.gov/Archives/edgar/data/104581...  2025-10-24
# 3    https://www.sec.gov/Archives/edgar/data/104581...         NaN  33
# 4    https://www.sec.gov/Archives/edgar/data/104581...         NaN  33
# ..                                                 ...         ...  ..
# 995  https://www.sec.gov/Archives/edgar/data/104581...  2019-05-23
# ...
